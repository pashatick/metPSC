# %%
import requests
import json
main = 'http://api.vk.com/method/'
method = 'gifts.get'
u_a = {'User-Agents':'Mozilla/5.0'}
id = 'user_id=143057454'
token = 'access_token=8e689054acc6eb812062bb622fe5f81f723a94cbb1798c4472d9c81fa72ee2590713d1250233397477d81'
res = requests.get(f'{main}{method}?{id}&{token}&v=5.101', headers=u_a)
res.json()
# Out:
# {'response': {'count': 37,
#   'items': [{'id': -1846982167,
#     'from_id': 124911067,
#     'message': '',
#     'date': 1568316135,
#     'gift': {'id': 1041,
#      'thumb_256': 'https://vk.com/images/gift/1041/256.jpg',
#      'thumb_96': 'https://vk.com/images/gift/1041/96.png',
#      'thumb_48': 'https://vk.com/images/gift/1041/48.png'},
#     'privacy': 0},
#    {'id': -1846982439,
#     'from_id': 124911067,
#     'message': '',
#     'date': 1568316128,
#     'gift': {'id': 1039,
#      'thumb_256': 'https://vk.com/images/gift/1039/256.jpg',
#      'thumb_96': 'https://vk.com/images/gift/1039/96.png',
#      'thumb_48': 'https://vk.com/images/gift/1039/48.png'},
#     'privacy': 0},
#    {'id': -2017370779,
#     'from_id': 124911067,
#     'message': '',
#     'date': 1557378661,
#     'gift': {'id': 711,
#      'thumb_256': 'https://vk.com/images/gift/711/256.jpg',
#      'thumb_96': 'https://vk.com/images/gift/711/96.png',
# ...
